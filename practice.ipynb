# %%
import requests

# %%
import requests

def fetch_random_product():
    url = "https://api.freeapi.app/api/v1/public/randomproducts/product/random"

    response = requests.get(url)
    data = response.json()

    if response.status_code == 200:

        product = data["data"]["price"]

        brand = product["brand"]
        category = product["category"]

        return product

    else:
        raise Exception(f"Failed to fetch data: {response.status_code}")


def main():
    try:
        product = fetch_random_product()
        print(f"Brand: {print}")

    except Exception as e:
        print(e)


if __name__ == "__main__":
    main()
# Out:
# 'int' object is not subscriptable

# %%
import requests

response = requests.get(
    "https://api.freeapi.app/api/v1/public/randomproducts/product/random"
)

data = response.json()

from pprint import pprint
pprint(data)

product = data["data"]["category"]
print(product)
# Out:
# {'data': {'brand': 'Rubber',
#           'category': 'mens-shoes',
#           'description': 'Men Shoes - Loafers for men - Rubber Shoes - Nylon '
#                          'Shoes - Shoes for men - Moccassion - Pure Nylon '
#                          '(Rubber) Expot Quality.',
#           'discountPercentage': 10.91,
#           'id': 57,
#           'images': ['https://cdn.dummyjson.com/product-images/57/1.jpg',
#                      'https://cdn.dummyjson.com/product-images/57/2.jpg',
#                      'https://cdn.dummyjson.com/product-images/57/3.jpg',
#                      'https://cdn.dummyjson.com/product-images/57/4.jpg',
#                      'https://cdn.dummyjson.com/product-images/57/thumbnail.jpg'],
#           'price': 47,
#           'rating': 4.91,
#           'stock': 20,
#           'thumbnail': 'https://cdn.dummyjson.com/product-images/57/thumbnail.jpg',
#           'title': 'Loafers for men'},
#  'message': 'Random product fetched successfully',
#  'statusCode': 200,
#  'success': True}
# mens-shoes

# %%
category = data.get("data", {}).get("category")
print(category)
# Out:
# mens-shoes
